# %%
file_list = ['First Extract.csv','Second Extract.csv','Third Extract.csv','Fourth Extract.csv','Fifth Extract.csv','Sixth Extract.csv','Seventh Extract.csv']

# %%
import os
import pandas as pd
path = '/content/drive/MyDrive/이재명'

# %%
df = pd.DataFrame()
for file in file_list:
    df2 = pd.read_csv(os.path.join(path, file), low_memory=False)
    df.append(df2)

# %%
df1= pd.read_csv('/content/drive/MyDrive/이재명/First Extract.csv')
df2= pd.read_csv('/content/drive/MyDrive/이재명/Second Extract.csv')
df3= pd.read_csv('/content/drive/MyDrive/이재명/Third Extract.csv')
df4= pd.read_csv('/content/drive/MyDrive/이재명/Fourth Extract.csv')
df5= pd.read_csv('/content/drive/MyDrive/이재명/Fifth Extract.csv')
df6= pd.read_csv('/content/drive/MyDrive/이재명/Sixth Extract.csv')
df7= pd.read_csv('/content/drive/MyDrive/이재명/Seventh Extract.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(len(df1), len( df2), len(df3), len(df4), len(df5), len(df6), len(df7))
# Out:
# 100001 48905 100001 100001 55285 100001 96874

# %%
len(df1)+ len( df2)+len(df3)+ len(df4)+ len(df5)+ len(df6)+ len(df7)
# Out:
# 601068

# %%
df = pd.DataFrame()
df = pd.concat([df1, df2, df3, df4, df5, df6, df7])

# %%
len(df)
# Out:
# 601068

# %%
df=df.drop('Unnamed: 0', axis=1)

# %%
new_index = [i for i in range(len(df))]
df.index = new_index

# %%
df
# Out:
#                                                       url  ... cashtags
# 0       https://twitter.com/leciel0375/status/14629339...  ...      NaN
# 1       https://twitter.com/squarehead1975/status/1462...  ...      NaN
# 2       https://twitter.com/zesters98/status/146293388...  ...      NaN
# 3       https://twitter.com/jayko2020/status/146293386...  ...      NaN
# 4       https://twitter.com/2580friend78/status/146293...  ...      NaN
# ...                                                   ...  ...      ...
# 601063  https://twitter.com/kim_edit/status/1432855962...  ...      NaN
# 601064  https://twitter.com/cwZICRFIxl77WNW/status/143...  ...      NaN
# 601065  https://twitter.com/minchol0VeS2/status/143285...  ...      NaN
# 601066  https://twitter.com/sQPFntqnz6nr7xa/status/143...  ...      NaN
# 601067  https://twitter.com/truthkks/status/1432855797...  ...      NaN
#
# [601068 rows x 27 columns]

# %%
df.to_csv('/content/drive/MyDrive/이재명/lee.csv')

# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/drive/MyDrive/이재명/lee.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1 = df1.drop(['Unnamed: 0'], axis=1)

# %%
df2 = pd.read_csv('/content/drive/MyDrive/이재명/lee_1123.csv')

# %%
df3 = pd.read_csv('/content/drive/MyDrive/이재명/lee_1124_1129.csv')

# %%
df4 = pd.read_csv('/content/drive/MyDrive/이재명/lee_1129.csv')

# %%
df5 = pd.read_csv('/content/drive/MyDrive/이재명/lee_1130.csv')

# %%
print(len(df1), len(df2), len(df3), len(df4), len(df5))
# Out:
# 601068 5220 35702 7803 6045

# %%
len(df1)+ len(df2)+ len(df3)+ len(df4)+ len(df5)
# Out:
# 655838

# %%
df = pd.concat([df1, df2, df3, df4, df5])

# %%
len(df)
# Out:
# 655838

# %%
idx = []
for i in range(len(df)):
  idx.append(i)

# %%
df.index = idx

# %%
df
# Out:
#                                                       url  ... Unnamed: 0
# 0       https://twitter.com/leciel0375/status/14629339...  ...        NaN
# 1       https://twitter.com/squarehead1975/status/1462...  ...        NaN
# 2       https://twitter.com/zesters98/status/146293388...  ...        NaN
# 3       https://twitter.com/jayko2020/status/146293386...  ...        NaN
# 4       https://twitter.com/2580friend78/status/146293...  ...        NaN
# ...                                                   ...  ...        ...
# 655833  https://twitter.com/clementia2017/status/14654...  ...     6040.0
# 655834  https://twitter.com/sweetthmj/status/146547069...  ...     6041.0
# 655835  https://twitter.com/lee63636/status/1465470657...  ...     6042.0
# 655836  https://twitter.com/jungseok2530/status/146547...  ...     6043.0
# 655837  https://twitter.com/DotFace/status/14654706385...  ...     6044.0
#
# [655838 rows x 28 columns]

# %%
df.to_csv('/content/drive/MyDrive/이재명/lee_0901_1130_raw.csv', index=False)

# %%
df_lee_tweet=pd.DataFrame(df.content)

# %%
df_lee_tweet.to_csv('/content/drive/MyDrive/이재명/lee_tweet.csv', index=False)

# %%
pd.read_csv('/content/drive/MyDrive/이재명/lee_tweet.csv')
# Out:
#                                                   content
# 0       하나같이 국짐당 의원들은 누가 써준거 읽는거 말곤 자기가 할줄 아는 말들이 하나도 ...
# 1       이준석-박철민 친분 주장..."방명록과 수사보고서 등 근거 있어"(김진태) / 이재...
# 2       '패완얼'이란 말이 한동안 유행했었다.\n\n패션의 완성은 얼굴..이라는 뜻.\n\...
# 3       윤석열 vs 이재명 인성 논란? 이 영상 하나로 종결 짓습니다. (+심각한 언론 형...
# 4       [네이버 블로그]\n‘개발이익 환수하라’더니 ‘공급절벽이니 하지 말라’는 보수언론,...
# ...                                                   ...
# 655833  여성들은 윤석열도 극혐하는 사람이 많아서 이재명 대신 윤 찍으라고 설득하는 데에 한...
# 655834  와 이재명이 집에 쟁여둔 돈의 비밀이 이런거구나 지역상품권 만들어서 받은 돈세탁한 ...
# 655835  송영길, 이준석에 "이재명 부부싸움 유언비어.. '크라켄' 작동해 국민의힘 지지자 ...
# 655836                            @Jaemyung_Lee 말은 이미ㅏㄴ기네
# 655837  대선 주자들은 합창하듯 집을 더 많이 짓겠다고 이야기하고 있어요.\n더불어민주당 이...
#
# [655838 rows x 1 columns]

# %%
leetweet = pd.read_csv('/content/drive/MyDrive/빅데이터 기말과제 파일공유/트위터/이재명/lee_0901_1130_raw.csv')
leetweet.info()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (26) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 655838 entries, 0 to 655837
# Data columns (total 28 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   url               655838 non-null  object
#  1   date              655838 non-null  object
#  2   content           655838 non-null  object
#  3   renderedContent   655838 non-null  object
#  4   id                655838 non-null  int64
#  5   user              655838 non-null  object
#  6   replyCount        655838 non-null  int64
#  7   retweetCount      655838 non-null  int64
#  8   likeCount         655838 non-null  int64
#  9   quoteCount        655838 non-null  int64
#  10  conversationId    655838 non-null  int64
# ...
